# %%
import os, re, h5py, shutil
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
pwd
# Out:
# '/home/ubuntu/Downloads/FERG_DB_256'

# %%
os.rename("/home/ubuntu/Downloads/FERG_DB_256/Angry/aia_anger_1.png", "/home/ubuntu/Downloads/FERG_DB_256/Images/aia_anger_1.png")

# %%
os.rename("/home/ubuntu/Downloads/FERG_DB_256/Images/aia_anger_1.png", "/home/ubuntu/Downloads/FERG_DB_256/Angry/aia_anger_1.png")

# %%
# import shutil
# import os

# source1 = '/home/ubuntu/Downloads/FERG_DB_256/Angry'
# source2 = '/home/ubuntu/Downloads/FERG_DB_256/Fear'
# source3 = '/home/ubuntu/Downloads/FERG_DB_256/Disgust'
# source4 = '/home/ubuntu/Downloads/FERG_DB_256/Joy'
# source5 = '/home/ubuntu/Downloads/FERG_DB_256/Sadness'
# source6 = '/home/ubuntu/Downloads/FERG_DB_256/Neutral'
# source7 = '/home/ubuntu/Downloads/FERG_DB_256/Suprise'
# dest = '/home/ubuntu/Downloads/FERG_DB_256/Images'

# #sources = [source1, source2, source3, source4, source5, source6, source7]
# files = os.listdir(source1)

# for f in files:
#     if (f.startswith("aia") or f.startswith("bonnie") or f.startswith("jules") or f.startswith("mery") or f.startswith("ray")):
#         shutil.move(f, dest)
# #     elif (f.startswith("Intel") or f.startswith("intel")):
# #         shutil.move(f, dest)

# %%
from os import listdir
directory = "/home/ubuntu/Downloads/FERG_DB_256/Images"
files_dir =  listdir(directory)
newlist = []
for names in files_dir:
    if names.endswith(".png"):
        newlist.append(names)
print (newlist)
# Out:
# ['aia_anger_1000.png', 'aia_anger_1001.png', 'aia_anger_1002.png', 'aia_anger_1003.png', 'aia_anger_1004.png', 'aia_anger_1005.png', 'aia_anger_1006.png', 'aia_anger_1007.png', 'aia_anger_1008.png', 'aia_anger_1009.png', 'aia_anger_100.png', 'aia_anger_1010.png', 'aia_anger_1011.png', 'aia_anger_1012.png', 'aia_anger_1013.png', 'aia_anger_1014.png', 'aia_anger_1015.png', 'aia_anger_1016.png', 'aia_anger_1017.png', 'aia_anger_1018.png', 'aia_anger_1019.png', 'aia_anger_101.png', 'aia_anger_1020.png', 'aia_anger_1021.png', 'aia_anger_1022.png', 'aia_anger_1023.png', 'aia_anger_1024.png', 'aia_anger_1025.png', 'aia_anger_1026.png', 'aia_anger_1027.png', 'aia_anger_1028.png', 'aia_anger_1029.png', 'aia_anger_102.png', 'aia_anger_1030.png', 'aia_anger_1031.png', 'aia_anger_1032.png', 'aia_anger_1033.png', 'aia_anger_1034.png', 'aia_anger_1035.png', 'aia_anger_1036.png', 'aia_anger_1037.png', 'aia_anger_1038.png', 'aia_anger_1039.png', 'aia_anger_103.png', 'aia_anger_1040.png', 'aia_anger_
# ...

# %%
len(newlist)
# Out:
# 55767
